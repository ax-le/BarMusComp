# %%
import barmuscomp.ae_utils as ae_utils
import barmuscomp.ae as ae
import barmuscomp.lra as lra
import barmuscomp.scripts.default_path as paths
import barmuscomp.scripts.overall_scripts as scr

import as_seg.CBM_algorithm as CBM
import as_seg.barwise_input as bi
import as_seg.data_manipulation as dm
import as_seg.autosimilarity_computation as as_comp
#import as_seg.barwise_input as bi
from barmuscomp.model.current_plot import *

import math
import numpy as np
import pandas as pd
import mirdata
import os
import tensorly as tl

# %%
colors = ['tab:green', 'tab:purple','tab:red','tab:olive']
markers = ['^', 's', 'o','v']

convolution_type = "14_bands"
autosimilarity_types = ["Cosine", "Covariance", "RBF"]
pen_function = "modulo8"
feature = "pcp"
init_nmf = "nndsvd"

compression_labels = ["NMF", "PCA", "SSAE"]

dimensions_range = [8,16,24,32,40]

# %%
def return_results(references_segments, segments_in_time):
    prec05, rap05, f_mes05 = dm.compute_score_of_segmentation(references_segments, segments_in_time, window_length = 0.5)
    prec3, rap3, f_mes3 = dm.compute_score_of_segmentation(references_segments, segments_in_time, window_length = 3)
    return [[round(prec05,4),round(rap05,4),round(f_mes05,4)], [round(prec3,4),round(rap3,4),round(f_mes3,4)]]

# %%
def plot_kernels_as(results_diff_as, kernels_or_features, autosimilarities, tol, title = None):
    # Order results_diff_as: kernels ou features, as, tol
    subaxis = autosimilarities
    plt.rcParams.update({'font.size': 14})
    
    width=0.25
    gap = (len(autosimilarities) + 1)*width
    colors = ["#62d5b4", "#317373", "#184a4a"]#['skyblue', 'steelblue', 'darkorange', 'brown']
    
    fig, ax = plt.subplots(1, 1, figsize=(11,4))
    ax.set_ylim( 25, 105 )
    tab = []
    current_start = 0
    for i in range(len(autosimilarities)):
        indexes = [current_start + j*gap for j in range(len(kernels_or_features))]
        tab.append(ax.bar(indexes, results_diff_as[:,i,tol], color=colors[i], width=width, align='edge'))
        for idx_x, x in enumerate(indexes):
            height = results_diff_as[idx_x, i, tol] 
            plt.text(x +width/2,height + 2, f"{height}%", ha='center', va='bottom', rotation = 90)
        current_start += width

    ax.set_xticks([current_start/2 + j*gap for j in range(len(kernels_or_features))])
    ax.set_xticklabels(kernels_or_features)
    if tol == 1:
        ax.legend(labels=subaxis, loc='lower left')
    else:
        ax.legend(labels=subaxis, loc='lower left')

    ax.set_ylabel("F measure (percentage)")
    #fig.savefig("C:/Users/amarmore/Desktop/Mes papiers/figures/results_barcomp_05.pdf", bbox_inches = "tight")#, format='png')
    if title != None:
        plt.title(title)
    plt.show()

# %% [markdown]
# # EUC

# %%
def compute_this_penalty_compression_euc(penalty_func, dim_patterns, autosimilarity_type = "cosine", feature = "nn_log_mel_grill", convolution_type = "14_bands"):
    idx_song_max = 101 # Should be 101 for all the dataset, other values should be for tests only
    songs_range = range(1,idx_song_max) 
    subdivision = 96
    hop_length = 32
    hop_length_seconds = hop_length/44100
    lambda_penalty = 1

    results_songs_methods = math.inf * np.ones((len(songs_range), 3, len(dim_patterns), 2, 3)) # Songs, autosimilarity types, tol, metrics

    for idx_song, song_name in enumerate(songs_range):
        spectrogram, bars, references_segments = scr.load_spec_annot_song_RWC(song_name, feature, hop_length)
        
        for idx_dc, dc in enumerate(dim_patterns):
            ### NMF
            #idx_method = 0
            try:
                Q_matrix_nmf = np.load(f"{paths.path_data_persisted_rwc}/nmf/Q_nmf_dim{dc}_updatehals_init{init_nmf}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}.npy", allow_pickle = True)
            except FileNotFoundError:
                Q_matrix_nmf = lra.get_nmf_projection(spectrogram, bars, dc, beta = 2, init = init_nmf)
                np.save(f"{paths.path_data_persisted_rwc}/nmf/Q_nmf_dim{dc}_updatehals_init{init_nmf}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}", Q_matrix_nmf)

            autosimilarity_nmf = as_comp.switch_autosimilarity(Q_matrix_nmf, similarity_type = autosimilarity_type, normalise = True)
            segments_nmf = CBM.compute_cbm(autosimilarity_nmf, penalty_weight = lambda_penalty, penalty_func = penalty_func, convolution_type = convolution_type)[0]                
            segments_nmf_in_time = dm.segments_from_bar_to_time(segments_nmf, bars)
            results_songs_methods[idx_song, 0, idx_dc] = return_results(references_segments, segments_nmf_in_time)
            
            ### PCA
            #idx_method = 1
            try:
                Q_matrix_pca = np.load(f"{paths.path_data_persisted_rwc}/pca/pca_dim{dc}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}.npy", allow_pickle = True)
            except FileNotFoundError:
                Q_matrix_pca = lra.get_pca_projection(spectrogram, bars, dc)
                np.save(f"{paths.path_data_persisted_rwc}/pca/pca_dim{dc}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}", Q_matrix_pca)

            autosimilarity_pca = as_comp.switch_autosimilarity(Q_matrix_pca, similarity_type = autosimilarity_type, normalise = True)
            segments_pca = CBM.compute_cbm(autosimilarity_pca, penalty_weight = lambda_penalty, penalty_func = penalty_func, convolution_type = convolution_type)[0]                
            segments_pca_in_time = dm.segments_from_bar_to_time(segments_pca, bars)
            results_songs_methods[idx_song, 1, idx_dc] = return_results(references_segments, segments_pca_in_time)


            ### AE
            #idx_method = 2
            Q_matrix_ae = np.load(f"{paths.path_data_persisted_rwc}/neural_nets/conv_4_16_k3_transk3_latentfc{dc}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}_initkaiming_lr0.001_nepochs1000.npy", allow_pickle = True)
            autosimilarity_ae = as_comp.switch_autosimilarity(Q_matrix_ae, similarity_type = autosimilarity_type, normalise = True)
            segments_ae = CBM.compute_cbm(autosimilarity_ae, penalty_weight = lambda_penalty, penalty_func = penalty_func, convolution_type = convolution_type)[0]                
            segments_ae_in_time = dm.segments_from_bar_to_time(segments_ae, bars)
            results_songs_methods[idx_song, 2, idx_dc] = return_results(references_segments, segments_ae_in_time)

            
    odd_songs = range(0,idx_song_max - 1,2) # Weird, but shouldn't confuse indexes and number
    even_songs = range(1,idx_song_max - 1,2)
    to_return = -math.inf * np.ones((3, 2, 3))
    
    for idx_method in range(3):
        avg_odd_songs = np.mean(results_songs_methods[odd_songs, idx_method,:,0, 2], axis = 0) + np.mean(results_songs_methods[odd_songs, idx_method,:,1, 2], axis = 0)

        best_idx_odd = np.argmax(avg_odd_songs)
        print(f"Odd, method {compression_labels[idx_method]}, best dc: {dim_patterns[best_idx_odd]}")
        res_odd = math.inf * np.ones((2,3))
        for tol in range(2):
            for metric in range(3):
                res_odd[tol, metric] = np.mean(results_songs_methods[even_songs, idx_method, best_idx_odd, tol, metric])
    
        avg_even_songs = np.mean(results_songs_methods[even_songs, idx_method,:,0, 2], axis = 0) + np.mean(results_songs_methods[even_songs, idx_method,:,1, 2], axis = 0)
        best_idx_even = np.argmax(avg_even_songs)
        print(f"Even, method {compression_labels[idx_method]}, best dc: {dim_patterns[best_idx_even]}")
        res_even = math.inf * np.ones((2,3))
        for tol in range(2):
            for metric in range(3):
                res_even[tol, metric] = np.mean(results_songs_methods[odd_songs, idx_method, best_idx_even, tol, metric])
   
        to_return[idx_method] = np.mean(np.array([res_odd, res_even]), axis=0)
    
    return to_return

# %%
print(f"Kernel: {convolution_type}")

res_avg_target = math.inf * np.ones((len(compression_labels), len(autosimilarity_types), 2, 3))

indexes = []
results_this_function = math.inf * np.ones((len(autosimilarity_types), 2, 3))
for idx_as, autosimil_type in enumerate(autosimilarity_types):
    print(f"Autosimilarity type: {autosimil_type}")
    res = compute_this_penalty_compression_euc(pen_function, dimensions_range, autosimilarity_type = autosimil_type, feature = feature, convolution_type = convolution_type)
    for idx_line, line in enumerate(res):
        res_avg_target[idx_line, idx_as] = line
    dataframe = pd.DataFrame(res.reshape(res.shape[0], 6), columns = ['P0.5', 'R0.5', 'F0.5','P3', 'R3', 'F3'], index = compression_labels)
    display(dataframe.style.bar(subset=["F0.5","F3"], color='#5fba7d'))
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), compression_labels, autosimilarity_types, 0, title = f"F0.5 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), compression_labels, autosimilarity_types, 1, title = f"F3 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
print("---------------\n------------\n------------\n------------\n------------")
# Out:
# Kernel: 14_bands
# Autosimilarity type: Cosine
# Odd, method NMF, best dc: 32
# Even, method NMF, best dc: 16
# Odd, method PCA, best dc: 24
# Even, method PCA, best dc: 40
# Odd, method SSAE, best dc: 24
# Even, method SSAE, best dc: 24
# <style  type="text/css" >
#     #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.7%, transparent 57.7%);
#         }    #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.4%, transparent 96.4%);
#         }</style><table id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5368</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col1" class="data row0 col1" >0.5834</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5545</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col3" class="data row0 col3" >0.7000</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7540</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row0_col5" class="data row0 col5" >0.7198</td>
#             </tr>
#             <tr>
#                         <th id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >PCA</th>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col0" class="data row1 col0" >0.4778</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col1" class="data row1 col1" >0.6386</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5331</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col3" class="data row1 col3" >0.6057</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8054</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row1_col5" class="data row1 col5" >0.6755</td>
#             </tr>
#             <tr>
#                         <th id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36level0_row2" class="row_heading level0 row2" >SSAE</th>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col0" class="data row2 col0" >0.5042</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col1" class="data row2 col1" >0.5128</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col2" class="data row2 col2" >0.5040</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col3" class="data row2 col3" >0.7213</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col4" class="data row2 col4" >0.7274</td>
#                         <td id="T_8d077f05_dc66_11ec_a8ec_8c04ba3e1d36row2_col5" class="data row2 col5" >0.7182</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: Covariance
# Odd, method NMF, best dc: 16
# Even, method NMF, best dc: 24
# Odd, method PCA, best dc: 24
# Even, method PCA, best dc: 40
# Odd, method SSAE, best dc: 24
# Even, method SSAE, best dc: 40
# <style  type="text/css" >
#     #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.7%, transparent 3.7%);
#         }    #T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.2%, transparent 26.2%);
#         }</style><table id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col0" class="data row0 col0" >0.4969</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col1" class="data row0 col1" >0.6628</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5561</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6076</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col4" class="data row0 col4" >0.8211</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row0_col5" class="data row0 col5" >0.6838</td>
#             </tr>
#             <tr>
#                         <th id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >PCA</th>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col0" class="data row1 col0" >0.4778</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col1" class="data row1 col1" >0.6386</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5331</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col3" class="data row1 col3" >0.6057</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8054</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row1_col5" class="data row1 col5" >0.6755</td>
#             </tr>
#             <tr>
#                         <th id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36level0_row2" class="row_heading level0 row2" >SSAE</th>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col0" class="data row2 col0" >0.4742</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col1" class="data row2 col1" >0.6449</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col2" class="data row2 col2" >0.5340</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col3" class="data row2 col3" >0.6036</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col4" class="data row2 col4" >0.8140</td>
#                         <td id="T_ff09321a_dc66_11ec_8720_8c04ba3e1d36row2_col5" class="data row2 col5" >0.6777</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: RBF
# Odd, method NMF, best dc: 24
# Even, method NMF, best dc: 16
# Odd, method PCA, best dc: 40
# Even, method PCA, best dc: 32
# Odd, method SSAE, best dc: 32
# Even, method SSAE, best dc: 40
# <style  type="text/css" >
#     #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.7%, transparent 5.7%);
#         }    #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 71.2%, transparent 71.2%);
#         }    #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5605</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col1" class="data row0 col1" >0.6410</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5910</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6896</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7881</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row0_col5" class="data row0 col5" >0.7266</td>
#             </tr>
#             <tr>
#                         <th id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >PCA</th>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col0" class="data row1 col0" >0.5517</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col1" class="data row1 col1" >0.6245</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5791</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col3" class="data row1 col3" >0.7116</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8045</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row1_col5" class="data row1 col5" >0.7467</td>
#             </tr>
#             <tr>
#                         <th id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36level0_row2" class="row_heading level0 row2" >SSAE</th>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col0" class="data row2 col0" >0.5559</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col1" class="data row2 col1" >0.6164</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col2" class="data row2 col2" >0.5784</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col3" class="data row2 col3" >0.7268</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col4" class="data row2 col4" >0.8025</td>
#                         <td id="T_5a254103_dc67_11ec_8199_8c04ba3e1d36row2_col5" class="data row2 col5" >0.7549</td>
#             </tr>
#     </tbody></table>
# ---------------
# ------------
# ------------
# ------------
# ------------

# %% [markdown]
# # BETA

# %%
def compute_this_penalty_compression_beta(penalty_func, dim_patterns, autosimilarity_type = "cosine", feature = "nn_log_mel_grill", convolution_type = "14_bands", beta = 1):
    idx_song_max = 101 # Should be 101 for all the dataset, other values should be for tests only
    songs_range = range(1,idx_song_max) 
    subdivision = 96
    hop_length = 32
    hop_length_seconds = hop_length/44100
    lambda_penalty = 1

    results_songs_methods = math.inf * np.ones((len(songs_range), 2, len(dim_patterns), 2, 3)) # Songs, autosimilarity types, tol, metrics

    for idx_song, song_name in enumerate(songs_range):
        spectrogram, bars, references_segments = scr.load_spec_annot_song_RWC(song_name, feature, hop_length)
        
        for idx_dc, dc in enumerate(dim_patterns):
            ### NMF
            #idx_method = 0
            try:
                Q_matrix_nmf = np.load(f"{paths.path_data_persisted_rwc}/nmf/Q_nmf_dim{dc}_updatemu_beta{beta}_init{init_nmf}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}.npy", allow_pickle = True)
            except FileNotFoundError:
                Q_matrix_nmf = lra.get_nmf_projection(spectrogram, bars, dc, beta = beta, init = init_nmf)
                np.save(f"{paths.path_data_persisted_rwc}/nmf/Q_nmf_dim{dc}_updatemu_beta{beta}_init{init_nmf}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}", Q_matrix_nmf)

            autosimilarity_nmf = as_comp.switch_autosimilarity(Q_matrix_nmf, similarity_type = autosimilarity_type, normalise = True)
            segments_nmf = CBM.compute_cbm(autosimilarity_nmf, penalty_weight = lambda_penalty, penalty_func = penalty_func, convolution_type = convolution_type)[0]                
            segments_nmf_in_time = dm.segments_from_bar_to_time(segments_nmf, bars)
            results_songs_methods[idx_song, 0, idx_dc] = return_results(references_segments, segments_nmf_in_time)
            
            ### AE
            #idx_method = 1
            Q_matrix_ae = np.load(f"{paths.path_data_persisted_rwc}/neural_nets/conv_4_16_k3_transk3_latentfc{dc}_song{song_name}_feature{feature}_hop{hop_length}_subdivbars{subdivision}_initkaiming_lr0.001_nepochs1000_beta{beta}.npy", allow_pickle = True)
            autosimilarity_ae = as_comp.switch_autosimilarity(Q_matrix_ae, similarity_type = autosimilarity_type, normalise = True)
            segments_ae = CBM.compute_cbm(autosimilarity_ae, penalty_weight = lambda_penalty, penalty_func = penalty_func, convolution_type = convolution_type)[0]                
            segments_ae_in_time = dm.segments_from_bar_to_time(segments_ae, bars)
            results_songs_methods[idx_song, 1, idx_dc] = return_results(references_segments, segments_ae_in_time)

            
    odd_songs = range(0,idx_song_max - 1,2) # Weird, but shouldn't confuse indexes and number
    even_songs = range(1,idx_song_max - 1,2)
    to_return = -math.inf * np.ones((2, 2, 3))
    
    for idx_method in range(2):
        avg_odd_songs = np.mean(results_songs_methods[odd_songs, idx_method,:,0, 2], axis = 0) + np.mean(results_songs_methods[odd_songs, idx_method,:,1, 2], axis = 0)

        best_idx_odd = np.argmax(avg_odd_songs)
        print(f"Odd, method {compression_labels[idx_method]}, best dc: {dim_patterns[best_idx_odd]}")
        res_odd = math.inf * np.ones((2,3))
        for tol in range(2):
            for metric in range(3):
                res_odd[tol, metric] = np.mean(results_songs_methods[even_songs, idx_method, best_idx_odd, tol, metric])
    
        avg_even_songs = np.mean(results_songs_methods[even_songs, idx_method,:,0, 2], axis = 0) + np.mean(results_songs_methods[even_songs, idx_method,:,1, 2], axis = 0)
        best_idx_even = np.argmax(avg_even_songs)
        print(f"Even, method {compression_labels[idx_method]}, best dc: {dim_patterns[best_idx_even]}")
        res_even = math.inf * np.ones((2,3))
        for tol in range(2):
            for metric in range(3):
                res_even[tol, metric] = np.mean(results_songs_methods[odd_songs, idx_method, best_idx_even, tol, metric])
   
        to_return[idx_method] = np.mean(np.array([res_odd, res_even]), axis=0)
    
    return to_return

# %% [markdown]
# ## Beta 1

# %%
print(f"Kernel: {convolution_type}")

beta_compression_labels = ["NMF", "SSAE"]
res_avg_target = math.inf * np.ones((len(beta_compression_labels), len(autosimilarity_types), 2, 3))

indexes = []
results_this_function = math.inf * np.ones((len(autosimilarity_types), 2, 3))
for idx_as, autosimil_type in enumerate(autosimilarity_types):
    print(f"Autosimilarity type: {autosimil_type}")
    res = compute_this_penalty_compression_beta(pen_function, dimensions_range, autosimilarity_type = autosimil_type, feature = feature, convolution_type = convolution_type, beta = 1)
    for idx_line, line in enumerate(res):
        res_avg_target[idx_line, idx_as] = line
    dataframe = pd.DataFrame(res.reshape(res.shape[0], 6), columns = ['P0.5', 'R0.5', 'F0.5','P3', 'R3', 'F3'], index = beta_compression_labels)
    display(dataframe.style.bar(subset=["F0.5","F3"], color='#5fba7d'))
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), beta_compression_labels, autosimilarity_types, 0, title = f"F0.5 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), beta_compression_labels, autosimilarity_types, 1, title = f"F3 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
print("---------------\n------------\n------------\n------------\n------------")
# Out:
# Kernel: 14_bands
# Autosimilarity type: Cosine
# Odd, method NMF, best dc: 32
# Even, method NMF, best dc: 40
# Odd, method PCA, best dc: 24
# Even, method PCA, best dc: 32
# <style  type="text/css" >
#     #T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5263</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col1" class="data row0 col1" >0.5530</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5339</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col3" class="data row0 col3" >0.7005</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7318</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row0_col5" class="data row0 col5" >0.7089</td>
#             </tr>
#             <tr>
#                         <th id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col0" class="data row1 col0" >0.5471</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col1" class="data row1 col1" >0.5824</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5588</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col3" class="data row1 col3" >0.7212</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col4" class="data row1 col4" >0.7640</td>
#                         <td id="T_4da0fd2d_dc69_11ec_af75_8c04ba3e1d36row1_col5" class="data row1 col5" >0.7351</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: Covariance
# Odd, method NMF, best dc: 32
# Even, method NMF, best dc: 24
# Odd, method PCA, best dc: 32
# Even, method PCA, best dc: 32
# <style  type="text/css" >
#     #T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col0" class="data row0 col0" >0.4969</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col1" class="data row0 col1" >0.6600</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5546</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6063</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col4" class="data row0 col4" >0.8061</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row0_col5" class="data row0 col5" >0.6771</td>
#             </tr>
#             <tr>
#                         <th id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col0" class="data row1 col0" >0.5056</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col1" class="data row1 col1" >0.6576</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5608</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col3" class="data row1 col3" >0.6337</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8247</td>
#                         <td id="T_8d24e8c9_dc69_11ec_919a_8c04ba3e1d36row1_col5" class="data row1 col5" >0.7036</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: RBF
# Odd, method NMF, best dc: 24
# Even, method NMF, best dc: 16
# Odd, method PCA, best dc: 24
# Even, method PCA, best dc: 40
# <style  type="text/css" >
#     #T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }</style><table id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5311</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col1" class="data row0 col1" >0.6033</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5584</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6797</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7665</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row0_col5" class="data row0 col5" >0.7120</td>
#             </tr>
#             <tr>
#                         <th id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col0" class="data row1 col0" >0.5796</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col1" class="data row1 col1" >0.6448</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col2" class="data row1 col2" >0.6044</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col3" class="data row1 col3" >0.7283</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8088</td>
#                         <td id="T_cc28f14f_dc69_11ec_8fac_8c04ba3e1d36row1_col5" class="data row1 col5" >0.7595</td>
#             </tr>
#     </tbody></table>
# ---------------
# ------------
# ------------
# ------------
# ------------

# %% [markdown]
# ## Beta 0

# %%
print(f"Kernel: {convolution_type}")

beta_compression_labels = ["NMF", "SSAE"]
res_avg_target = math.inf * np.ones((len(beta_compression_labels), len(autosimilarity_types), 2, 3))

indexes = []
results_this_function = math.inf * np.ones((len(autosimilarity_types), 2, 3))
for idx_as, autosimil_type in enumerate(autosimilarity_types):
    print(f"Autosimilarity type: {autosimil_type}")
    res = compute_this_penalty_compression_beta(pen_function, dimensions_range, autosimilarity_type = autosimil_type, feature = feature, convolution_type = convolution_type, beta = 0)
    for idx_line, line in enumerate(res):
        res_avg_target[idx_line, idx_as] = line
    dataframe = pd.DataFrame(res.reshape(res.shape[0], 6), columns = ['P0.5', 'R0.5', 'F0.5','P3', 'R3', 'F3'], index = beta_compression_labels)
    display(dataframe.style.bar(subset=["F0.5","F3"], color='#5fba7d'))
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), beta_compression_labels, autosimilarity_types, 0, title = f"F0.5 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
plot_kernels_as(np.round(100 * res_avg_target[:,:,:,2], decimals = 2), beta_compression_labels, autosimilarity_types, 1, title = f"F3 for Euclidean-NTD,\n14-bands kernel and modulo 8 penalty.")
print("---------------\n------------\n------------\n------------\n------------")
# Out:
# Kernel: 14_bands
# Autosimilarity type: Cosine
# Odd, method NMF, best dc: 24
# Even, method NMF, best dc: 32
# Odd, method PCA, best dc: 24
# Even, method PCA, best dc: 16
# <style  type="text/css" >
#     #T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5096</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col1" class="data row0 col1" >0.5448</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5210</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6843</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7305</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row0_col5" class="data row0 col5" >0.6995</td>
#             </tr>
#             <tr>
#                         <th id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col0" class="data row1 col0" >0.3753</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col1" class="data row1 col1" >0.3549</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col2" class="data row1 col2" >0.3620</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col3" class="data row1 col3" >0.6009</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col4" class="data row1 col4" >0.5668</td>
#                         <td id="T_a7cb9824_ddee_11ec_a8ec_8c04ba3e1d36row1_col5" class="data row1 col5" >0.5792</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: Covariance
# Odd, method NMF, best dc: 32
# Even, method NMF, best dc: 32
# Odd, method PCA, best dc: 40
# Even, method PCA, best dc: 40
# <style  type="text/css" >
#     #T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col0" class="data row0 col0" >0.4895</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col1" class="data row0 col1" >0.6215</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5378</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6095</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7791</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row0_col5" class="data row0 col5" >0.6720</td>
#             </tr>
#             <tr>
#                         <th id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col0" class="data row1 col0" >0.4235</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col1" class="data row1 col1" >0.5857</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col2" class="data row1 col2" >0.4821</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col3" class="data row1 col3" >0.5751</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col4" class="data row1 col4" >0.8019</td>
#                         <td id="T_d690dd19_ddee_11ec_8720_8c04ba3e1d36row1_col5" class="data row1 col5" >0.6568</td>
#             </tr>
#     </tbody></table>
# Autosimilarity type: RBF
# Odd, method NMF, best dc: 16
# Even, method NMF, best dc: 24
# Odd, method PCA, best dc: 40
# Even, method PCA, best dc: 40
# <style  type="text/css" >
#     #T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P0.5</th>        <th class="col_heading level0 col1" >R0.5</th>        <th class="col_heading level0 col2" >F0.5</th>        <th class="col_heading level0 col3" >P3</th>        <th class="col_heading level0 col4" >R3</th>        <th class="col_heading level0 col5" >F3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36level0_row0" class="row_heading level0 row0" >NMF</th>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col0" class="data row0 col0" >0.5051</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col1" class="data row0 col1" >0.5670</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col2" class="data row0 col2" >0.5280</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col3" class="data row0 col3" >0.6694</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col4" class="data row0 col4" >0.7530</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row0_col5" class="data row0 col5" >0.7005</td>
#             </tr>
#             <tr>
#                         <th id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36level0_row1" class="row_heading level0 row1" >SSAE</th>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col0" class="data row1 col0" >0.5097</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col1" class="data row1 col1" >0.5138</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col2" class="data row1 col2" >0.5078</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col3" class="data row1 col3" >0.6992</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col4" class="data row1 col4" >0.6995</td>
#                         <td id="T_073af6fc_ddef_11ec_8199_8c04ba3e1d36row1_col5" class="data row1 col5" >0.6942</td>
#             </tr>
#     </tbody></table>
# ---------------
# ------------
# ------------
# ------------
# ------------
